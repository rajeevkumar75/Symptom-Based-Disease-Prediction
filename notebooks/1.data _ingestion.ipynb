# %%
import os
import sys
import gdown

from src.logger import logger, CustomException
from src.utils.common import read_yaml, create_directories

# %%
# %pwd
# Out:
# 'c:\\Users\\Rajeev kumar\\Desktop\\Symptom-Based-Disease-Prediction\\notebooks'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'c:\\Users\\Rajeev kumar\\Desktop\\Symptom-Based-Disease-Prediction'

# %%
class DataIngestion:
    def __init__(self, config_path: str):
        try:
            self.config = read_yaml(config_path)
            self.ingestion_config = self.config["data_ingestion"]

            self.raw_data_dir = self.ingestion_config["raw_data_dir"]
            self.gdrive_folder_id = self.ingestion_config["gdrive_folder_id"]

        except Exception as e:
            raise CustomException(e, sys)

    def download_data(self):
        try:
            logger.info("Starting data ingestion")

            create_directories([self.raw_data_dir])

            logger.info("Downloading dataset folder from Google Drive")

            gdown.download_folder(
                id=self.gdrive_folder_id,
                output=self.raw_data_dir,
                quiet=False,
                use_cookies=False
            )

            logger.info(f"Dataset folder downloaded into {self.raw_data_dir}")
            return self.raw_data_dir

        except Exception as e:
            raise CustomException(e, sys)

# %%
if __name__ == "__main__":
    ingestion = DataIngestion(config_path="config/config.yaml")
    data_path = ingestion.download_data()
    print(f"Data available at: {data_path}")
# Out:
# [2026-02-13 21:09:00,175] INFO common:17 - YAML file loaded successfully: config/config.yaml
# [2026-02-13 21:09:00,175] INFO 1760108957:15 - Starting data ingestion
# [2026-02-13 21:09:00,176] INFO common:30 - Directory created: artifacts/raw
# [2026-02-13 21:09:00,177] INFO 1760108957:19 - Downloading dataset folder from Google Drive
# Retrieving folder contents
# Processing file 1x0MCNj-wmQHswpVNCNgQmvDyQTeRC7vo train_disease.csv
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1x0MCNj-wmQHswpVNCNgQmvDyQTeRC7vo
# To: c:\Users\Rajeev kumar\Desktop\Symptom-Based-Disease-Prediction\artifacts\raw\train_disease.csv
# 100%|██████████| 1.38M/1.38M [00:04<00:00, 279kB/s]
# [2026-02-13 21:09:10,432] INFO 1760108957:28 - Dataset folder downloaded into artifacts/raw
# Data available at: artifacts/raw
# Download completed
